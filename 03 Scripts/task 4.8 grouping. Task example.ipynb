# %% [markdown]
# # Task 4.8: Grouping Data & Aggregating Variables

# %% [markdown]
# ## 1. Grouping Data

# %% [markdown]
# ## 2. Aggregating Data with agg()

# %% [markdown]
# ## 3. Aggregating Data with transform()

# %% [markdown]
# ## 4. Deriving Columns with loc()

# %% [markdown]
# ## 1. Grouping Data

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\azikb\Downloads\Data Immersion. Assiginment 4. Python. Instacart Basket Analysis"

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_prods_merge.pkl'))

# %%
df = df_ords_prods_merge[:1000000]

# %%
df.groupby('product_name')

# %% [markdown]
# ## 2. Aggregating Data with agg()

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Getting the 'mean' using different method
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Getting the 'mean' using dot method
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ## 3. Aggregating Data with transform()

# %%
df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\azikb\AppData\Local\Temp\ipykernel_12564\3693603773.py:1: FutureWarning: The provided callable <function max at 0x0000027B486B47C0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)
# C:\Users\azikb\AppData\Local\Temp\ipykernel_12564\3693603773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df.head(15)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
#
#    product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0          Soda        77              7     9.0   both  Mid-range product
# 1          Soda        77              7     9.0   both  Mid-range product
# 2          Soda        77              7     9.0   both  Mid-range product
# 3          Soda        77              7     9.0   both  Mid-range product
# 4          Soda        77              7     9.0   both  Mid-range product
# 5          Soda        77              7     9.0   both  Mid-range product
# 6          Soda        77              7     9.0   both  Mid-range product
# 7          Soda        77              7     9.0   both  Mid-range product
# 8          Soda        77              7     9.0   both  Mid-range product
# 9          Soda        77              7     9.0   both  Mid-range product
# 10         Soda        77              7     9.0   both  Mid-range product
# 11         Soda        77              7     9.0   both  Mid-range product
# 12         Soda        77              7     9.0   both  Mid-range product
# 13         Soda        77              7     9.0   both  Mid-range product
# 14         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day busiest_period_of_day  max_order
# 0   Regulary days        Average orders         10
# 1    Slowest days        Average orders         10
# 2    Slowest days           Most orders         10
# 3    Slowest days        Average orders         10
# 4    Slowest days           Most orders         10
# 5   Regulary days        Average orders         10
# 6    Busiest days           Most orders         10
# 7    Busiest days           Most orders         10
# 8    Busiest days           Most orders         10
# 9    Slowest days        Average orders         10
# 10   Busiest days           Most orders         22
# 11  Regulary days           Most orders         22
# 12  Regulary days           Most orders         22
# 13   Busiest days           Most orders         22
# 14   Busiest days           Most orders         22

# %%
 df_ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# ..       ...      ...           ...                ...                ...
# 95   3226575      360             1                  5                 12
# 96   1469869      377             3                  5                 17
# 97   1927023      387             2                  4                 10
# 98    858092      420             4                  1                 19
# 99    119314      420             5                  3                 19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# ..                     ...         ...                ...        ...
# 95                     NaN         196                  1          0
# 96                     3.0         196                  9          0
# 97                    22.0         196                  3          0
# 98                    30.0         196                  2          0
# 99                    16.0         196                  2          1
#
#    product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0          Soda        77              7     9.0   both  Mid-range product
# 1          Soda        77              7     9.0   both  Mid-range product
# 2          Soda        77              7     9.0   both  Mid-range product
# 3          Soda        77              7     9.0   both  Mid-range product
# 4          Soda        77              7     9.0   both  Mid-range product
# ..          ...       ...            ...     ...    ...                ...
# 95         Soda        77              7     9.0   both  Mid-range product
# 96         Soda        77              7     9.0   both  Mid-range product
# 97         Soda        77              7     9.0   both  Mid-range product
# 98         Soda        77              7     9.0   both  Mid-range product
# 99         Soda        77              7     9.0   both  Mid-range product
#
#       busiest_day busiest_period_of_day
# 0   Regulary days        Average orders
# 1    Slowest days        Average orders
# 2    Slowest days           Most orders
# 3    Slowest days        Average orders
# 4    Slowest days           Most orders
# ..            ...                   ...
# 95  Regulary days           Most orders
# 96  Regulary days        Average orders
# 97   Slowest days           Most orders
# 98   Busiest days        Average orders
# 99   Slowest days        Average orders
#
# [100 rows x 17 columns]

# %%
# pd.options.display.max_rows = None

# %% [markdown]
# ## 4. Deriving Columns with loc()

# %%
ords_prods_merge = df_ords_prods_merge

# %%
df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\azikb\AppData\Local\Temp\ipykernel_12564\3586920424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    463844
# Loyal customer      335086
# New customer        201070
# Name: count, dtype: int64

# %%
df[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43      New customer             6
# 22       43      New customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3
